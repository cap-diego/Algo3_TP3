# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
test1 = pd.read_csv("soluciones.csv")
test1
test1=test1.drop(test1.index[24])
test1
# Out:
#      Instancia    n  capacidad-camion  k-opt  costo-opt Algoritmo  costo-sol  \
# 0    F-n135-k7  135              2210      7       1162      CRSA   1417.400
# 1   M-n101-k10  101               200     10        820      CRSA    860.759
# 2    F-n135-k7  135              2210      7       1162      CRSA   1417.400
# 3   M-n151-k12  151               200     12       1015      CRSA   1271.910
# 4    M-n121-k7  121               200      7       1034      CRSA   1175.160
# 5     P-n20-k2   20               160      2        216      CRSA    284.515
# 6     P-n50-k7   50               150      7        554      CRSA    652.746
# 7     P-n23-k8   23                40      8        529      CRSA    562.803
# 8     P-n40-k5   40               140      5        458      CRSA    520.762
# 9     P-n45-k5   45               150      5        510      CRSA    596.031
# 10    B-n50-k7   50               100      7        741      CRSA    791.597
# 11   B-n67-k10   67               100     10       1032      CRSA   1158.350
# 12    A-n32-k5   32               100      5        784      CRSA    905.395
# 13    A-n55-k9   55               100      9       1073      CRSA   1212.440
# 14    A-n65-k9   65               100      9       1174      CRSA   1364.140
# 15    P-n50-k7   50               150      7        554      CRSA    652.746
# 16   P-n60-k15   60                80     15        968      CRSA   1062.190
# 17   B-n78-k10   78               100     10       1221      CRSA   1318.990
# 18    B-n52-k7   52               100      7        747      CRSA    793.603
# 19    B-n31-k5   31               100      5        672      CRSA    680.028
# 20    B-n44-k7   44               100      7        909      CRSA   1011.190
# 21    B-n45-k5   45               100      5        751      CRSA    822.429
# 22    B-n45-k6   45               100      6        678      CRSA    780.475
# 23   E-n101-k8  101               200      8        815      CRSA   1033.210
# 25  E-n101-k14  101               112     14       1067      CRSA   1262.540
# 26   P-n101-k4  101               400      4        681      CRSA    889.118
# 27    P-n76-k5   76               280      5        627      CRSA    778.386
#
#     k-sol    tiempo
# 0       7   20478.5
# 1      10    7187.9
# 2       7   20361.4
# 3      12    3396.5
# 4       7    5375.2
# 5       2      49.3
# 6       7    2752.5
# 7       9  192898.0
# 8       5     109.2
# 9       5    1380.3
# 10      7    5477.0
# 11     10    9695.2
# 12      5      78.0
# 13      9    8982.0
# 14      9    4315.6
# 15      7    2300.8
# 16     16  287001.0
# 17     10    1964.1
# 18      7    1796.5
# 19      5     109.2
# 20      7    1095.2
# 21      5     390.0
# 22      7    2496.0
# 23      8    3427.1
# 25     14   66394.7
# 26      4     296.4
# 27      5    2654.5

# %%
t=t.sort_values('n')
#plt.plot(t['n'],t['tiempo'])
vec_difs=[]
plt.ylabel("t / n^3")
plt.xlabel("n")
vec_difs = t['k-sol'] - t['k'] 
vec_difs
t['dist-entre-kopt-y-k-sol'] = vec_difs
rel_n_k = t['n']/t['k']
t['rel-entre-n-y-k'] = rel_n_k
#t= t.drop(columns=['dist-entre-k'])
cub=[]
for i in range(len(t)):
    cub+=[t['n'][i] *t['n'][i]*t['n'][i]]
cub

vec_cub=t['n']*t['n']*t['n']

cdf = pd.DataFrame(cub)
tdf = pd.DataFrame(t['tiempo']/cdf)
plt.plot(t['n'], tdf)
plt.legend(['relacion de tiempos del algoritmo con n^3'])
t
# Out:
#      Instancia    n  capacidad   k Algoritmo  costo-ruteo  k-sol    tiempo  \
# 22    p-n16-k8   16         35   8    C-RS-A      462.689      8   21799.6
# 21    p-n20-k2   20        160   2    C-RS-A      284.515      2      62.4
# 19    p-n23-k8   23         40   8    C-RS-A      562.803      9  191702.0
# 3     e-n30-k3   30       4500   3    C-RS-A      560.939      4    1067.8
# 14    b-n31-k5   31        100   5    C-RS-A      680.028      5      93.6
# 6     a-n32-k5   32        100   5    C-RS-A      905.395      5      86.4
# 18    p-n40-k5   40        140   5    C-RS-A      520.762      5     109.2
# 9     b-n44-k7   44        100   7    C-RS-A     1011.190      7    1046.2
# 17    p-n45-k5   45        150   5    C-RS-A      596.031      5    1404.0
# 11    b-n45-k6   45        100   6    C-RS-A      780.475      7    2621.4
# 20    p-n50-k7   50        150   7    C-RS-A      652.746      7    2250.4
# 16    b-n50-k7   50        100   7    C-RS-A      791.597      7    5210.8
# 12    b-n52-k7   52        100   7    C-RS-A      793.603      7    1841.8
# 5     a-n55-k9   55        100   9    C-RS-A     1212.440      9    8771.6
# 10   b-n63-k10   63        100  10    C-RS-A     1633.950     10   11419.8
# 8    b-n63-k10   63        100  10    C-RS-A     1633.950     10   11205.8
# 7     a-n65-k9   65        100   9    C-RS-A     1364.140      9    4556.6
# 15   b-n67-k10   67        100  10    C-RS-A     1158.350     10    9910.4
# 4    e-n76-k14   76        100  14    C-RS-A     1169.260     16   33116.0
# 13   b-n78-k10   78        100  10    C-RS-A     1318.990     10    2049.6
# 2   M-n101-k10  101        200  10    C-RS-A      860.759     10    7094.4
# 1    M-n121-k7  121        200   7    C-RS-A     1175.160      7    5334.6
# 24   F-n135-k7  135       2210   7      CRSA     1417.400      7   20358.2
# 0   M-n151-k12  151        200  12    C-RS-A     1271.910     12    3442.0
# 23           M  200        200  17      CRSA     1554.950     17  200112.0
#
#     rel-entre-n-y-k  dist-entre-kopt-y-k-sol
# 22         2.000000                        0
# 21        10.000000                        0
# 19         2.875000                        1
# 3         10.000000                        1
# 14         6.200000                        0
# 6          6.400000                        0
# 18         8.000000                        0
# 9          6.285714                        0
# 17         9.000000                        0
# 11         7.500000                        1
# 20         7.142857                        0
# 16         7.142857                        0
# 12         7.428571                        0
# 5          6.111111                        0
# 10         6.300000                        0
# 8          6.300000                        0
# 7          7.222222                        0
# 15         6.700000                        0
# 4          5.428571                        2
# 13         7.800000                        0
# 2         10.100000                        0
# 1         17.285714                        0
# 24        19.285714                        0
# 0         12.583333                        0
# 23        11.764706                        0
